# %%
import pandas as pd
import numpy as np
import requests
import time
from io import StringIO
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Choose starting point url

# %%
url = "https://fbref.com/en/comps/"
data = requests.get(url)

# %%
desired_competition_ids = ['37','24','9','12','13','20','11','32','10']

# %% [markdown]
# Create a list of all the male competitions on FBREF

# %%
soup = BeautifulSoup(data.text)
table1 = soup.find("table", {"id": "comps_1_fa_club_league_senior"})
male_comps_table1 = table1.find_all("tr", {"class": "gender-m"})

table2 = soup.find("table", {"id": "comps_2_fa_club_league_senior"})
male_comps_table2 = table2.find_all("tr", {"class": "gender-m"})

male_comps = male_comps_table1 + male_comps_table2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[480], line 3
#       1 soup = BeautifulSoup(data.text)
#       2 table1 = soup.find("table", {"id": "comps_1_fa_club_league_senior"})
# ----> 3 male_comps_table1 = table1.find_all("tr", {"class": "gender-m"})
#       5 table2 = soup.find("table", {"id": "comps_2_fa_club_league_senior"})
#       6 male_comps_table2 = table2.find_all("tr", {"class": "gender-m"})
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# Debug: Print number of rows found
print(f"Total male_comps rows found: {len(male_comps)}")

# Filter rows based on desired competition IDs
filtered_male_comps = []
for row in male_comps:
    # Find the href attribute of the first <a> tag in the row
    a_tag = row.find("a", href=True)
    if a_tag:
        row_href = a_tag["href"]
        print(f"Found href: {row_href}")  # Debug: Print each href found
        # Extract competition ID using regex
        match = re.search(r'/en/comps/(\d+)/', row_href)
        if match:
            comp_id = match.group(1)
            print(f"Competition ID extracted: {comp_id}")  # Debug: Print competition ID
            if comp_id in desired_competition_ids:
                print(f"Match found for competition ID: {comp_id}")  # Debug: Print if match is found
                filtered_male_comps.append(row)

# Debug: Print number of rows after filtering
print(f"Filtered male_comps rows: {len(filtered_male_comps)}")
# Out:
# Total male_comps rows found: 63
# Found href: /en/comps/21/history/Liga-Profesional-Argentina-Seasons
# Competition ID extracted: 21
# Found href: /en/comps/65/history/A-League-Men-Seasons
# Competition ID extracted: 65
# Found href: /en/comps/56/history/Austrian-Bundesliga-Seasons
# Competition ID extracted: 56
# Found href: /en/comps/37/history/Belgian-Pro-League-Seasons
# Competition ID extracted: 37
# Match found for competition ID: 37
# Found href: /en/comps/74/history/Bolivian-Primera-Division-Seasons
# Competition ID extracted: 74
# Found href: /en/comps/24/history/Serie-A-Seasons
# Competition ID extracted: 24
# Match found for competition ID: 24
# Found href: /en/comps/67/history/Bulgarian-First-League-Seasons
# Competition ID extracted: 67
# Found href: /en/comps/211/history/Canadian-Premier-League-Seasons
# Competition ID extracted: 211
# Found href: /en/comps/35/history/Primera-Division-Seasons
# Competition ID extracted: 35
# Found href: /en/comps/62/history/Chinese-Super-League-Seasons
# Competition ID extracted: 62
# Found href: /en/comps/41/history/Primera-A-Seasons
# Competition ID extracted: 41
# Found href: /en/comps/63/history/Hrvatska-NL-Seasons
# Competition ID extracted: 63
# Found href: /en/comps/66/history/Czech-First-League-Seasons
# Competition ID extracted: 66
# Found href: /en/comps/50/history/Danish-Superliga-Seasons
# Competition ID extracted: 50
# Found href: /en/comps/58/history/Serie-A-Seasons
# Competition ID extracted: 58
# Found href: /en/comps/9/history/Premier-League-Seasons
# Competition ID extracted: 9
# Match found for competition ID: 9
# Found href: /en/comps/12/history/La-Liga-Seasons
# Competition ID extracted: 12
# Match found for competition ID: 12
# Found href: /en/comps/43/history/Veikkausliiga-Seasons
# Competition ID extracted: 43
# Found href: /en/comps/13/history/Ligue-1-Seasons
# Competition ID extracted: 13
# Match found for competition ID: 13
# Found href: /en/comps/20/history/Bundesliga-Seasons
# Competition ID extracted: 20
# Match found for competition ID: 20
# Found href: /en/comps/27/history/Super-League-Greece-Seasons
# Competition ID extracted: 27
# Found href: /en/comps/46/history/NB-I-Seasons
# Competition ID extracted: 46
# Found href: /en/comps/82/history/Indian-Super-League-Seasons
# Competition ID extracted: 82
# Found href: /en/comps/64/history/Persian-Gulf-Pro-League-Seasons
# Competition ID extracted: 64
# Found href: /en/comps/11/history/Serie-A-Seasons
# Competition ID extracted: 11
# Match found for competition ID: 11
# Found href: /en/comps/25/history/J1-League-Seasons
# Competition ID extracted: 25
# Found href: /en/comps/55/history/K-League-1-Seasons
# Competition ID extracted: 55
# Found href: /en/comps/70/history/Saudi-Professional-League-Seasons
# Competition ID extracted: 70
# Found href: /en/comps/31/history/Liga-MX-Seasons
# Competition ID extracted: 31
# Found href: /en/comps/23/history/Eredivisie-Seasons
# Competition ID extracted: 23
# Found href: /en/comps/28/history/Eliteserien-Seasons
# Competition ID extracted: 28
# Found href: /en/comps/61/history/Primera-Division-Seasons
# Competition ID extracted: 61
# Found href: /en/comps/44/history/Liga-1-Seasons
# Competition ID extracted: 44
# Found href: /en/comps/36/history/Ekstraklasa-Seasons
# Competition ID extracted: 36
# Found href: /en/comps/32/history/Primeira-Liga-Seasons
# Competition ID extracted: 32
# Match found for competition ID: 32
# Found href: /en/comps/47/history/Liga-I-Seasons
# Competition ID extracted: 47
# Found href: /en/comps/52/history/Premier-Division-Seasons
# Competition ID extracted: 52
# Found href: /en/comps/30/history/Russian-Premier-League-Seasons
# Competition ID extracted: 30
# Found href: /en/comps/40/history/Scottish-Premiership-Seasons
# Competition ID extracted: 40
# Found href: /en/comps/54/history/Serbian-SuperLiga-Seasons
# Competition ID extracted: 54
# Found href: /en/comps/57/history/Swiss-Super-League-Seasons
# Competition ID extracted: 57
# Found href: /en/comps/29/history/Allsvenskan-Seasons
# Competition ID extracted: 29
# Found href: /en/comps/26/history/Super-Lig-Seasons
# Competition ID extracted: 26
# Found href: /en/comps/39/history/Ukrainian-Premier-League-Seasons
# Competition ID extracted: 39
# Found href: /en/comps/45/history/Uruguayan-Primera-Division-Seasons
# Competition ID extracted: 45
# Found href: /en/comps/22/history/Major-League-Soccer-Seasons
# Competition ID extracted: 22
# Found href: /en/comps/105/history/Venezuelan-Primera-Division-Seasons
# Competition ID extracted: 105
# Found href: /en/comps/69/history/Challenger-Pro-League-Seasons
# Competition ID extracted: 69
# Found href: /en/comps/38/history/Serie-B-Seasons
# Competition ID extracted: 38
# Found href: /en/comps/10/history/Championship-Seasons
# Competition ID extracted: 10
# Match found for competition ID: 10
# Found href: /en/comps/17/history/Segunda-Division-Seasons
# Competition ID extracted: 17
# Found href: /en/comps/60/history/Ligue-2-Seasons
# Competition ID extracted: 60
# Found href: /en/comps/33/history/2-Bundesliga-Seasons
# Competition ID extracted: 33
# Found href: /en/comps/378/history/I-League-Seasons
# Competition ID extracted: 378
# Found href: /en/comps/18/history/Serie-B-Seasons
# Competition ID extracted: 18
# Found href: /en/comps/49/history/J2-League-Seasons
# Competition ID extracted: 49
# Found href: /en/comps/51/history/Eerste-Divisie-Seasons
# Competition ID extracted: 51
# Found href: /en/comps/72/history/Scottish-Championship-Seasons
# Competition ID extracted: 72
# Found href: /en/comps/48/history/Superettan-Seasons
# Competition ID extracted: 48
# Found href: /en/comps/76/history/NASL-Seasons
# Competition ID extracted: 76
# Found href: /en/comps/73/history/USL-Championship-Seasons
# Competition ID extracted: 73
# Found href: /en/comps/68/history/USL-D-1-Seasons
# Competition ID extracted: 68
# Found href: /en/comps/79/history/D2-Pro-League-Seasons
# Competition ID extracted: 79
# Filtered male_comps rows: 9

# %%
filtered_male_comps
# Out:
# [<tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/37/history/Belgian-Pro-League-Seasons">Belgian Pro League</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/BEL/Belgium-Football"><span class="f-i f-be" style="">be</span></a> <a href="/en/country/BEL/Belgium-Football">BEL</a></td><td class="left" csk="2003-2004" data-stat="minseason"><a href="/en/comps/37/2003-2004/2003-2004-Belgian-Pro-League-Stats">2003-2004</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/37/Belgian-Pro-League-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/24/history/Serie-A-Seasons">Campeonato Brasileiro Série A</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/BRA/Brazil-Football"><span class="f-i f-br" style="">br</span></a> <a href="/en/country/BRA/Brazil-Football">BRA</a></td><td class="left" csk="2014-2014" data-stat="minseason"><a href="/en/comps/24/2014/2014-Serie-A-Stats">2014</a></td><td class="left" csk="2024-2024" data-stat="maxseason"><a href="/en/comps/24/Serie-A-Stats">2024</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/9/history/Premier-League-Seasons">Premier League</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/ENG/England-Football"><span class="f-i f-gb-eng" style="">eng</span></a> <a href="/en/country/ENG/England-Football">ENG</a></td><td class="left" csk="1888-1889" data-stat="minseason"><a href="/en/comps/9/1888-1889/1888-1889-Premier-League-Stats">1888-1889</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/9/Premier-League-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/12/history/La-Liga-Seasons">La Liga</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/ESP/Spain-Football"><span class="f-i f-es" style="">es</span></a> <a href="/en/country/ESP/Spain-Football">ESP</a></td><td class="left" csk="1988-1989" data-stat="minseason"><a href="/en/comps/12/1988-1989/1988-1989-La-Liga-Stats">1988-1989</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/12/La-Liga-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/13/history/Ligue-1-Seasons">Ligue 1</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/FRA/France-Football"><span class="f-i f-fr" style="">fr</span></a> <a href="/en/country/FRA/France-Football">FRA</a></td><td class="left" csk="1995-1996" data-stat="minseason"><a href="/en/comps/13/1995-1996/1995-1996-Ligue-1-Stats">1995-1996</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/13/Ligue-1-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/20/history/Bundesliga-Seasons">Fußball-Bundesliga</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/GER/Germany-Football"><span class="f-i f-de" style="">de</span></a> <a href="/en/country/GER/Germany-Football">GER</a></td><td class="left" csk="1988-1989" data-stat="minseason"><a href="/en/comps/20/1988-1989/1988-1989-Bundesliga-Stats">1988-1989</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/20/Bundesliga-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/11/history/Serie-A-Seasons">Serie A</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/ITA/Italy-Football"><span class="f-i f-it" style="">it</span></a> <a href="/en/country/ITA/Italy-Football">ITA</a></td><td class="left" csk="1988-1989" data-stat="minseason"><a href="/en/comps/11/1988-1989/1988-1989-Serie-A-Stats">1988-1989</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/11/Serie-A-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/32/history/Primeira-Liga-Seasons">Primeira Liga</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/POR/Portugal-Football"><span class="f-i f-pt" style="">pt</span></a> <a href="/en/country/POR/Portugal-Football">POR</a></td><td class="left" csk="2000-2001" data-stat="minseason"><a href="/en/comps/32/2000-2001/2000-2001-Primeira-Liga-Stats">2000-2001</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/32/Primeira-Liga-Stats">2024-2025</a></td></tr>,
#  <tr class="gender-m"><th class="left" data-stat="league_name" scope="row"><a href="/en/comps/10/history/Championship-Seasons">EFL Championship</a></th><td class="center" data-stat="gender">M</td><td class="left" data-stat="country"><a href="/en/country/ENG/England-Football"><span class="f-i f-gb-eng" style="">eng</span></a> <a href="/en/country/ENG/England-Football">ENG</a></td><td class="left" csk="2001-2002" data-stat="minseason"><a href="/en/comps/10/2001-2002/2001-2002-Championship-Stats">2001-2002</a></td><td class="left" csk="2024-2025" data-stat="maxseason"><a href="/en/comps/10/Championship-Stats">2024-2025</a></td></tr>]

# %% [markdown]
# Loop through the rows and create a link for each competition

# %%
links = []
for row in filtered_male_comps:
    row_links = [l.get("href") for l in row.find_all("a") if '/comps/' in l.get("href")]
    if len(row_links) >= 2:
        links.append(row_links[0])
        
    comps_urls = [f"https://fbref.com{l}" for l in links]
    
    time.sleep(3)

# %%
comps_urls
# Out:
# ['https://fbref.com/en/comps/37/history/Belgian-Pro-League-Seasons',
#  'https://fbref.com/en/comps/24/history/Serie-A-Seasons',
#  'https://fbref.com/en/comps/9/history/Premier-League-Seasons',
#  'https://fbref.com/en/comps/12/history/La-Liga-Seasons',
#  'https://fbref.com/en/comps/13/history/Ligue-1-Seasons',
#  'https://fbref.com/en/comps/20/history/Bundesliga-Seasons',
#  'https://fbref.com/en/comps/11/history/Serie-A-Seasons',
#  'https://fbref.com/en/comps/32/history/Primeira-Liga-Seasons',
#  'https://fbref.com/en/comps/10/history/Championship-Seasons']

# %% [markdown]
# Loop through all competition links to find each season you want. Then loop through every item in that season to create the urls for each season. Lastly loop through each url and create a stats version of that url which has the player stats

# %%
# Initialize the list to store the final stats URLs
season_stats_urls = []

for url in comps_urls:
    try:
        # Fetch the page content
        data = requests.get(url)
        soup = BeautifulSoup(data.text, 'html.parser')

        # Find the table with seasons
        seasons_table = soup.find("table", {"id": "seasons"})
        if not seasons_table:
            raise ValueError("Table with ID 'seasons' not found")
        
        # Find the first two relevant season rows (skipping the header)
        season_rows = seasons_table.find_all("tr")[1:3]

        for row in season_rows:
            # Extract links that contain '/comps/' in the href attribute
            row_links = [l.get("href") for l in row.find_all("a") if '/comps/' in l.get("href")]
            
            # If there are at least 2 such links, use the first one to construct the season URL
            if len(row_links) >= 2:
                season_url = f"https://fbref.com{row_links[0]}"
                
                # Modify the season URL to get the stats version
                stats_url = re.sub(r'(/[^/]+)$', r'/stats\1', season_url)
                
                # Add the stats URL to the final list
                season_stats_urls.append(stats_url)
        
        print(f"{url}: Done")
        
        # Optional delay between requests
        time.sleep(3)
    
    except Exception as e:
        print(f"{url}: {type(e).__name__} - {str(e)}")
        print(f"HTML content: {soup.prettify()}")

# Now you have all the season_stats_urls ready in one loop
# Out:
# https://fbref.com/en/comps/37/history/Belgian-Pro-League-Seasons: Done
# https://fbref.com/en/comps/24/history/Serie-A-Seasons: Done
# https://fbref.com/en/comps/9/history/Premier-League-Seasons: Done
# https://fbref.com/en/comps/12/history/La-Liga-Seasons: Done
# https://fbref.com/en/comps/13/history/Ligue-1-Seasons: Done
# https://fbref.com/en/comps/20/history/Bundesliga-Seasons: Done
# https://fbref.com/en/comps/11/history/Serie-A-Seasons: Done
# https://fbref.com/en/comps/32/history/Primeira-Liga-Seasons: Done
# https://fbref.com/en/comps/10/history/Championship-Seasons: Done

# %%
season_stats_urls
# Out:
# ['https://fbref.com/en/comps/37/stats/Belgian-Pro-League-Stats',
#  'https://fbref.com/en/comps/37/2023-2024/stats/2023-2024-Belgian-Pro-League-Stats',
#  'https://fbref.com/en/comps/24/stats/Serie-A-Stats',
#  'https://fbref.com/en/comps/24/2023/stats/2023-Serie-A-Stats',
#  'https://fbref.com/en/comps/9/stats/Premier-League-Stats',
#  'https://fbref.com/en/comps/9/2023-2024/stats/2023-2024-Premier-League-Stats',
#  'https://fbref.com/en/comps/12/stats/La-Liga-Stats',
#  'https://fbref.com/en/comps/12/2023-2024/stats/2023-2024-La-Liga-Stats',
#  'https://fbref.com/en/comps/13/stats/Ligue-1-Stats',
#  'https://fbref.com/en/comps/13/2023-2024/stats/2023-2024-Ligue-1-Stats',
#  'https://fbref.com/en/comps/20/stats/Bundesliga-Stats',
#  'https://fbref.com/en/comps/20/2023-2024/stats/2023-2024-Bundesliga-Stats',
#  'https://fbref.com/en/comps/11/stats/Serie-A-Stats',
#  'https://fbref.com/en/comps/11/2023-2024/stats/2023-2024-Serie-A-Stats',
#  'https://fbref.com/en/comps/32/stats/Primeira-Liga-Stats',
#  'https://fbref.com/en/comps/32/2023-2024/stats/2023-2024-Primeira-Liga-Stats',
#  'https://fbref.com/en/comps/10/stats/Championship-Stats',
#  'https://fbref.com/en/comps/10/2023-2024/stats/2023-2024-Championship-Stats']

# %%
all_dfs = []
for url in season_stats_urls:
    data = requests.get(url).text.replace("<!--", "").replace("-->", "")
    soup = BeautifulSoup(data)
    header = soup.find("h2").find("span").text
    season, comp_name = header.split(" ", 1) 
    country = soup.find("a", href=lambda href: href and '/country/' in href).text
    
    table = soup.find("table", {"id": "stats_standard"})
    ids = [x["data-append-csv"] for x in table.find_all("td", {"data-stat": "player"})]

    df = pd.read_html(StringIO(str(table)))[0]
    df.columns = [f"{i} {j}" if "Unnamed" not in i else j for i, j in df.columns]
    df = df.loc[df["Rk"] != "Rk"]
    df["Fbref"] = ids
    df['Season'] = season
    df['Competition'] = comp_name
    df['Country'] = country
    
    cols_to_move = ['Fbref', 'Season', 'Competition', 'Country']
    remaining_cols = [col for col in df.columns if col not in cols_to_move]
    new_order = remaining_cols[:1] + cols_to_move + remaining_cols[1:]
        
    df = df[new_order]
    df = df.rename({'Playing Time MP': 'MP','Playing Time Starts': 'Starts', 'Playing Time Min': 'Min', 'Playing Time 90s': '90s', 'Per 90 Minutes npxG': 'npxG', 'Per 90 Minutes xAG': 'xAG'}, axis=1)
    df = df.groupby(['Fbref', 'Season', 'Competition', 'Country', 'Player', 'Squad', 'Age']).agg(lambda x: pd.to_numeric(x, errors='coerce').mean())[['MP', 'Starts', 'Min', '90s', 'npxG', 'xAG']].reset_index()
    
    all_dfs.append(df)
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[486], line 5
#       3 data = requests.get(url).text.replace("<!--", "").replace("-->", "")
#       4 soup = BeautifulSoup(data)
# ----> 5 header = soup.find("h2").find("span").text
#       6 season, comp_name = header.split(" ", 1)
#       7 country = soup.find("a", href=lambda href: href and '/country/' in href).text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
all_players = pd.concat(all_dfs)

# %%
all_players.head(20)
# Out:
#        Fbref     Season         Competition  Country  \
# 0   003d8899  2024-2025  Belgian Pro League  Belgium
# 1   028b8d59  2024-2025  Belgian Pro League  Belgium
# 2   051e11ca  2024-2025  Belgian Pro League  Belgium
# 3   074e1710  2024-2025  Belgian Pro League  Belgium
# 4   07caccd9  2024-2025  Belgian Pro League  Belgium
# 5   098525c6  2024-2025  Belgian Pro League  Belgium
# 6   0a6dbbf7  2024-2025  Belgian Pro League  Belgium
# 7   0abcb968  2024-2025  Belgian Pro League  Belgium
# 8   0beabf0a  2024-2025  Belgian Pro League  Belgium
# 9   0c317bc1  2024-2025  Belgian Pro League  Belgium
# 10  0cb35466  2024-2025  Belgian Pro League  Belgium
# 11  0cdb6a2a  2024-2025  Belgian Pro League  Belgium
# 12  0d3585b5  2024-2025  Belgian Pro League  Belgium
# 13  0db5d2c8  2024-2025  Belgian Pro League  Belgium
# 14  0de73fa4  2024-2025  Belgian Pro League  Belgium
# 15  112bd859  2024-2025  Belgian Pro League  Belgium
# 16  132d6c0e  2024-2025  Belgian Pro League  Belgium
# 17  1495e7a9  2024-2025  Belgian Pro League  Belgium
# 18  14c7f64a  2024-2025  Belgian Pro League  Belgium
# 19  16c149b8  2024-2025  Belgian Pro League  Belgium
#
#                       Player          Squad     Age   MP  Starts    Min  90s  \
# 0           Takahiro Akimoto      OH Leuven  26-205  4.0     4.0  360.0  4.0
# 1               Archie Brown           Gent  22-087  4.0     4.0  357.0  4.0
# 2             Alouis Diriken   Sint-Truiden  20-232  2.0     2.0  147.0  1.6
# 3               Mike Penders           Genk  19-023  2.0     2.0  180.0  2.0
# 4             Amine Boukamir      Charleroi  17-305  1.0     0.0   11.0  0.1
# 5                Tobe Leysen      OH Leuven  22-167  4.0     4.0  360.0  4.0
# 6            Brandon Mechele    Club Brugge  31-208  4.0     4.0  360.0  4.0
# 7             Rafik Belghali       Mechelen  22-077  2.0     0.0   50.0  0.6
# 8               Joaquin Seys    Club Brugge  19-148  4.0     3.0  235.0  2.6
# 9            Malcolm Viltard         Dender  21-304  4.0     3.0  266.0  3.0
# 10        Kevin Mac Allister       Union SG  26-290  4.0     4.0  360.0  4.0
# 11    Matias Fernandez-Pardo           Gent  19-202  3.0     2.0  164.0  1.8
# 12              Kévin Denkey  Cercle Brugge  23-267  4.0     4.0  360.0  4.0
# 13         Mathias Jørgensen     Anderlecht  34-122  1.0     1.0   90.0  1.0
# 14            Alhassan Yusuf        Antwerp  24-036  1.0     0.0    7.0  0.1
# 15               Dire Mebude       Westerlo  20-087  4.0     4.0  271.0  3.0
# 16             Emir Ortakaya       Westerlo  20-062  1.0     0.0   45.0  0.5
# 17              Nathan Rôdes         Dender  26-256  4.0     4.0  335.0  3.7
# 18  D'Margio Wright-Phillips      Beerschot  22-334  4.0     0.0   49.0  0.5
# 19             Núrio Fortuna           Gent  29-152  1.0     0.0    3.0  0.0
#
#     npxG   xAG
# 0   0.02  0.02
# 1   0.03  0.04
# 2   0.00  0.00
# 3   0.00  0.00
# 4   0.00  0.00
# 5   0.00  0.00
# 6   0.03  0.02
# 7   0.00  0.00
# 8   0.08  0.12
# 9   0.05  0.01
# 10  0.07  0.00
# 11  0.60  0.00
# 12  0.38  0.24
# 13  0.05  0.82
# 14  0.00  0.00
# 15  0.63  0.13
# 16  0.00  0.00
# 17  0.00  0.00
# 18  0.05  0.00
# 19  1.31  0.00

# %%
all_players['Season'].unique()
# Out:
# array(['2024-2025', '2023-2024', '2024', '2023'], dtype=object)

# %%
all_players.query('Fbref == "220c11f1"').sort_values(by= 'npxG' , ascending=False).head(20)
# Out:
#        Fbref     Season Competition Country            Player   Squad     Age  \
# 50  220c11f1  2024-2025     La Liga   Spain  Cristhian Stuani  Girona  37-316
# 92  220c11f1  2023-2024     La Liga   Spain  Cristhian Stuani  Girona      36
#
#       MP  Starts    Min  90s  npxG   xAG
# 50   1.0     0.0   10.0  0.1  1.68  0.00
# 92  31.0     5.0  804.0  8.9  1.08  0.21

# %%
def fetch_players(url):
    with requests.Session() as session:
        html = session.get(url).text.replace("<!--", "").replace("-->", "")

    soup = BeautifulSoup(html, "html.parser")
    table = soup.find("table", {"id": "stats_standard"})
    ids = [x["data-append-csv"] for x in table.find_all("td", {"data-stat": "player"})]

    df = pd.read_html(StringIO(str(table)))[0]
    df.columns = [f"{i} {j}" if "Unnamed" not in i else j for i, j in df.columns]
    df = df.loc[df["Rk"] != "Rk"]
    df["fbref"] = ids
    
    df = df['fbref','Player', 'Squad', 'Age', 'Playing Time MP', 'Playing Time Starts', 'Playing Time Min', 'Playing Time 90s', 'Per 90 Minutes npxG', 'Per 90 Minutes xAG']
    df = df.rename({'Playing Time MP': 'MP','Playing Time Starts': 'Starts', 'Playing Time Min': 'Min', 'Playing Time 90s': '90s', 'Per 90 Minutes npxG': 'npxG', 'Per 90 Minutes xAG': 'xAG'}, axis=1)
    df = df.groupby(['fbref','Player', 'Squad', 'Age']).agg(lambda x: pd.to_numeric(x, errors='coerce').mean())[['MP', 'Starts', 'Min', '90s', 'npxG', 'xAG']].reset_index()
    
    return df

# %%
prem_url = "https://fbref.com/en/comps/9/2023-2024/stats/2023-2024-Premier-League-Stats"
champ_url = "https://fbref.com/en/comps/10/2023-2024/stats/2023-2024-Championship-Stats"

# %%
prem_df = fetch_players(prem_url)
champ_df = fetch_players(champ_url)

# %%
champ_df['npxG'] = np.round(champ_df['npxG']*0.71, 2)
champ_df['xAG'] = np.round(champ_df['xAG']*0.71, 2)

# %%
players_df = pd.concat([prem_df, champ_df], ignore_index=True)

# %%
players_df
# Out:
#          fbref                   Player            Squad Age    MP  Starts  \
# 0     00242715          Moussa Niakhate  Nott'ham Forest  27  21.0    15.0
# 1     003cf4d1             Jayden Danns        Liverpool  17   2.0     0.0
# 2     00953a9d              Mikey Moore        Tottenham  15   2.0     0.0
# 3     00963611  Konstantinos Mavropanos         West Ham  25  19.0    16.0
# 4     00b77ecf            Nathan Fraser           Wolves  18   7.0     1.0
# ...        ...                      ...              ...  ..   ...     ...
# 1304  fd45ca7b             Ryan Leonard         Millwall  31  35.0    31.0
# 1305  fd985c15          Harry Pickering        Blackburn  24  36.0    35.0
# 1306  fe558029             Mark Travers       Stoke City  24  13.0    13.0
# 1307  ff9fcd4d           Alex Pritchard  Birmingham City  30   9.0     3.0
# 1308  ff9fcd4d           Alex Pritchard       Sunderland  30  23.0     9.0
#
#          Min   90s  npxG   xAG
# 0     1460.0  16.2  0.07  0.01
# 1        9.0   0.1  0.00  0.00
# 2        4.0   0.0  0.00  0.00
# 3     1500.0  16.7  0.07  0.01
# 4      186.0   2.1  0.16  0.04
# ...      ...   ...   ...   ...
# 1304  2711.0  30.1  0.03  0.05
# 1305  3000.0  33.3  0.02  0.06
# 1306  1170.0  13.0  0.00  0.00
# 1307   333.0   3.7  0.05  0.03
# 1308  1128.0  12.5  0.11  0.21
#
# [1309 rows x 10 columns]

# %%
master = pd.read_csv("C:/Users/erknud3/fpl-optimization/model/data/Master.csv")
master = master.loc[master['24-25'].notna(), ['first_name', 'second_name', 'web_name', '24-25', 'fbref']]
master['24-25'] = master['24-25'].astype(int)
master = master.rename({'24-25': 'fpl_id'}, axis=1)

# %%
master.dtypes
# Out:
# first_name     object
# second_name    object
# web_name       object
# fpl_id          int32
# fbref          object
# dtype: object

# %%
r = requests.get("https://fantasy.premierleague.com/api/bootstrap-static/")
fpl_data = r.json()
elements = pd.DataFrame(fpl_data["elements"])
elements = elements[['id', 'team', 'element_type', 'now_cost', 'selected_by_percent']]
elements.loc[elements.element_type == 1, 'position'] ='GKP'
elements.loc[elements.element_type == 2, 'position'] ='DEF'
elements.loc[elements.element_type == 3, 'position'] ='MID'
elements.loc[elements.element_type == 4, 'position'] ='FWD'
elements = elements.rename({"selected_by_percent": "tsb"}, axis=1)
elements['now_cost'] = np.round(elements['now_cost'] / 10, 1)

# %%
f = requests.get("https://fantasy.premierleague.com/api/fixtures/")
fixtures = pd.DataFrame(f.json())
fixtures = fixtures[['event', 'team_h', 'team_a']]

# %%
fixtures
# Out:
#      event  team_h  team_a
# 0        1      14       9
# 1        1      10      12
# 2        1       1      20
# 3        1       8       5
# 4        1      15      17
# ..     ...     ...     ...
# 375     38      15       8
# 376     38      16       6
# 377     38      17       1
# 378     38      18       5
# 379     38      20       4
#
# [380 rows x 3 columns]

# %%
fpl_players = players_df.merge(master, on='fbref', how='inner')

# %%
fpl_players = fpl_players.merge(elements, left_on='fpl_id', right_on='id', how='inner')

# %%
fpl_players = fpl_players[['fbref', 'fpl_id', 'Player', 'web_name', 'element_type', 'now_cost', 'tsb', 'position', 'Age', 'MP', 'Starts', 'Min', '90s', 'npxG', 'xAG']]

# %%
fpl_players = fpl_players.groupby(['fbref', 'fpl_id', 'Player', 'web_name', 'element_type', 'now_cost', 'tsb', 'position', 'Age']).agg({
    'MP': 'sum', 
    'Starts': 'sum', 
    'Min': 'sum', 
    '90s': 'sum',
    'npxG': 'mean', 
    'xAG': 'mean'
}).reset_index()

# %%
for col in ['MP', 'Starts', 'Min', '90s']:
    fpl_players[col] = fpl_players[col].astype(int)
    
for col in ['npxG', 'xAG']:
    fpl_players[col] = np.round(fpl_players[col].astype(float), 2)

# %%
fpl_players.sort_values(by= 'npxG' , ascending=False).head(20)
# Out:
#         fbref  fpl_id              Player       web_name  element_type  \
# 262  95bd120d     165   Deivid Washington         Deivid             4
# 233  8450467d     260       Ali Al Hamadi      Al-Hamadi             4
# 28   123d2733     519       George Earthy         Earthy             3
# 52   1f44ac21     351      Erling Haaland        Haaland             4
# 474  f8eca1b6      65           Enes Ünal      Enes Ünal             4
# 139  4bcf39f6     229         Neal Maupay         Maupay             4
# 144  4d77b365     316        Darwin Núñez         Darwin             4
# 413  da2b8db3     276      Freddie Ladapo         Ladapo             4
# 369  c596fcb0     421       Callum Wilson         Wilson             4
# 425  dd745366     150       Andrey Santos  Andrey Santos             3
# 252  8e92be30     401      Alexander Isak           Isak             4
# 286  9c36ed83     180     Nicolas Jackson      N.Jackson             4
# 147  4e9a0555     447          Chris Wood           Wood             4
# 476  fa031b34     497         Richarlison    Richarlison             4
# 460  ed5c0319     218                Beto           Beto             4
# 33   15f24fe7     555      Sasa Kalajdzic      Kalajdžić             4
# 167  5a7301ae      33  Leander Dendoncker     Dendoncker             3
# 438  e342ad68     328       Mohamed Salah        M.Salah             3
# 39   17695062      19    Emile Smith Rowe     Smith Rowe             3
# 314  a755db8c     251       Rodrigo Muniz          Muniz             4
#
#      now_cost   tsb position Age  MP  Starts   Min  90s  npxG   xAG
# 262       5.0   0.1      FWD  18   2       0    13    0  3.23  0.00
# 233       5.0   0.4      FWD  21  14       1   293    3  0.99  0.11
# 28        4.5   0.2      MID  18   3       0    34    0  0.82  0.00
# 52       15.0  49.1      FWD  23  31      29  2552   28  0.81  0.15
# 474       5.5   0.1      FWD  26  16       2   328    3  0.80  0.28
# 139       5.0   1.7      FWD  26  31      14  1432   15  0.77  0.11
# 144       7.5   6.2      FWD  24  36      22  2047   22  0.68  0.27
# 413       4.5   2.1      FWD  30  17       2   350    3  0.67  0.05
# 369       7.0   0.2      FWD  31  20       9   991   11  0.65  0.05
# 425       4.5   0.0      MID  19   1       0     8    0  0.64  0.00
# 252       8.5  58.6      FWD  23  30      27  2255   25  0.62  0.15
# 286       7.5   2.1      FWD  22  35      31  2799   31  0.60  0.14
# 147       6.0   5.1      FWD  31  31      20  1812   20  0.59  0.10
# 476       7.0   1.1      FWD  26  28      18  1491   16  0.58  0.13
# 460       5.0   0.4      FWD  25  30       9   951   10  0.57  0.09
# 33        5.0   0.1      FWD  26  11       1   166    1  0.57  0.52
# 167       4.5   0.9      MID  28   8       1   119    1  0.56  0.00
# 438      12.5  33.8      MID  31  32      28  2534   28  0.55  0.42
# 39        5.5  14.8      MID  23  13       3   353    3  0.50  0.06
# 314       6.0   7.0      FWD  22  26      18  1593   17  0.49  0.12

# %%
player_csv_file_path = "C:/Users/erknud3/fpl-optimization/model/data/player_season_data.csv"

fpl_players.to_csv(player_csv_file_path, index=False)

# %%
# Step 1: Merge master_table with players_df using fbref id
player_stats = pd.merge(master, players_df, on='fbref', how='inner')

# %%
player_stats
# Out:
#             first_name                second_name   web_name  fpl_id  \
# 0                James                     Milner     Milner     134
# 1                James                  Tarkowski  Tarkowski     236
# 2               Ashley                      Young      Young     238
# 3                 John                      Ruddy      Ruddy     414
# 4               Łukasz                  Fabiański  Fabianski     521
# ..                 ...                        ...        ...     ...
# 510               Mark                   O’Mahony   O’Mahony     138
# 511            Murillo  Santiago Costa dos Santos    Murillo     436
# 512               Leon                    Chiwome    Chiwome     539
# 513               Enso                   González   Gonzalez     547
# 514  Deivid Washington           de Souza Eugênio     Deivid     165
#
#         fbref             Player            Squad Age    MP  Starts     Min  \
# 0    2f90f6b8       James Milner         Brighton  37  15.0    11.0   773.0
# 1    15ea812b    James Tarkowski          Everton  30  38.0    38.0  3419.0
# 2    be927d03       Ashley Young          Everton  38  31.0    27.0  2280.0
# 3    da8b19e2         John Ruddy  Birmingham City  36  44.0    44.0  3960.0
# 4    9328b835   Łukasz Fabiański         West Ham  38  10.0     7.0   721.0
# ..        ...                ...              ...  ..   ...     ...     ...
# 510  a3afdd69      Mark O'Mahony         Brighton  18   3.0     1.0    63.0
# 511  1704b0b8            Murillo  Nott'ham Forest  21  32.0    32.0  2789.0
# 512  a2852b4f       Leon Chiwome           Wolves  17   3.0     2.0   174.0
# 513  7e5bebeb      Enso Gonzalez           Wolves  18   1.0     0.0     1.0
# 514  95bd120d  Deivid Washington          Chelsea  18   2.0     0.0    13.0
#
#       90s  npxG   xAG   id  team  element_type  now_cost   tsb position
# 0     8.6  0.03  0.21  134     5             3       5.0   0.1      MID
# 1    38.0  0.07  0.06  236     8             2       5.0   2.2      DEF
# 2    25.3  0.02  0.06  238     8             2       4.5   0.2      DEF
# 3    44.0  0.00  0.00  414    15             1       4.0   0.3      GKP
# 4     8.0  0.00  0.00  521    19             1       4.0  12.7      GKP
# ..    ...   ...   ...  ...   ...           ...       ...   ...      ...
# 510   0.7  0.08  0.00  138     5             4       4.5   0.5      FWD
# 511  31.0  0.06  0.04  436    16             2       4.5   0.6      DEF
# 512   1.9  0.05  0.00  539    20             4       4.5   0.2      FWD
# 513   0.0  0.00  0.00  547    20             3       4.5   0.0      MID
# 514   0.1  3.23  0.00  165     6             4       5.0   0.1      FWD
#
# [515 rows x 20 columns]

# %%
# Step 1: Merge master_table with players_df using fbref id
player_stats = pd.merge(master, players_df, on='fbref', how='inner')

# Step 2: Merge with elements to get team_id for each player
player_stats = pd.merge(player_stats, elements, left_on='fpl_id', right_on='id', how='inner')

# Step 3: Merge player stats with fixtures table based on the team being in either team_h or team_a
fact_table_home = pd.merge(player_stats, fixtures, left_on='team', right_on='team_h', how='inner')
fact_table_home['home_or_away'] = 'H'
fact_table_home['team_facing'] = fact_table_home['team_a']

fact_table_away = pd.merge(player_stats, fixtures, left_on='team', right_on='team_a', how='inner')
fact_table_away['home_or_away'] = 'A'
fact_table_away['team_facing'] = fact_table_away['team_h']

# Combine the home and away matches into one fact table
fact_table = pd.concat([fact_table_home, fact_table_away], ignore_index=True)

# Cleanup to only keep necessary columns
fact_table = fact_table[['fbref', 'fpl_id', 'team', 'event', 'team_facing', 'home_or_away']]

# %%
fact_table_csv_file_path = "C:/Users/erknud3/fpl-optimization/model/data/fact_table.csv"

fact_table.to_csv(fact_table_csv_file_path, index=False)

# %%
fact_table.sort_values(by=['fpl_id','event'], ascending=True).head(40)
# Out:
#           fbref  fpl_id  team  event  team_facing home_or_away
# 6840   6412cc03       1     1      1           20            H
# 16625  6412cc03       1     1      2            2            A
# 6841   6412cc03       1     1      3            5            H
# 16626  6412cc03       1     1      4           18            A
# 16627  6412cc03       1     1      5           13            A
# 6842   6412cc03       1     1      6           11            H
# 6843   6412cc03       1     1      7           17            H
# 16628  6412cc03       1     1      8            3            A
# 6844   6412cc03       1     1      9           12            H
# 16629  6412cc03       1     1     10           15            A
# 16630  6412cc03       1     1     11            6            A
# 6845   6412cc03       1     1     12           16            H
# 16631  6412cc03       1     1     13           19            A
# 6846   6412cc03       1     1     14           14            H
# 16632  6412cc03       1     1     15            9            A
# 6847   6412cc03       1     1     16            8            H
# 16633  6412cc03       1     1     17            7            A
# 6848   6412cc03       1     1     18           10            H
# 16634  6412cc03       1     1     19            4            A
# 16635  6412cc03       1     1     20            5            A
# 6849   6412cc03       1     1     21           18            H
# 6850   6412cc03       1     1     22            2            H
# 16636  6412cc03       1     1     23           20            A
# 6851   6412cc03       1     1     24           13            H
# 16637  6412cc03       1     1     25           11            A
# 6852   6412cc03       1     1     26           19            H
# 16638  6412cc03       1     1     27           16            A
# 16639  6412cc03       1     1     28           14            A
# 6853   6412cc03       1     1     29            6            H
# 6854   6412cc03       1     1     30            9            H
# 16640  6412cc03       1     1     31            8            A
# 6855   6412cc03       1     1     32            4            H
# 16641  6412cc03       1     1     33           10            A
# 6856   6412cc03       1     1     34            7            H
# 6857   6412cc03       1     1     35            3            H
# 16642  6412cc03       1     1     36           12            A
# 6858   6412cc03       1     1     37           15            H
# 16643  6412cc03       1     1     38           17            A
# 4085   b66315ae       2     1      1           20            H
# 13870  b66315ae       2     1      2            2            A
