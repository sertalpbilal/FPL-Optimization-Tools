# %%
import pandas as pd
import sasoptpy as so

# %%
df = pd.read_csv('../data/input.csv')

# %%
df.head()
# Out:
#   Pos        Name    BV    SV     Team  27_xMins  27_Pts
# 0   M        Özil   6.7   6.7  Arsenal         0   0.000
# 1   D    Sokratis   4.8   4.8  Arsenal         0   0.000
# 2   D  David Luiz   5.4   5.4  Arsenal        60   2.766
# 3   M  Aubameyang  11.3  11.3  Arsenal        65   4.322
# 4   D      Cédric   4.6   4.6  Arsenal        15   0.696

# %%
gk_data = df[df['Pos'] == 'G'].copy().reset_index()

# %%
gk_data.head()
# Out:
#    index Pos      Name   BV   SV         Team  27_xMins  27_Pts
# 0      7   G      Leno  5.0  5.0      Arsenal        88   4.059
# 1     11   G  Martínez  5.3  4.9  Aston Villa        89   3.755
# 2     27   G    Heaton  4.5  4.5  Aston Villa         0   0.000
# 3     31   G     Steer  3.9  3.9  Aston Villa         0   0.000
# 4     34   G    Nyland  4.0  4.0  Aston Villa         0   0.000

# %%
model = so.Model(name='gk_model')
# Out:
# NOTE: Initialized model gk_model.

# %%
gk_data.set_index('index', inplace=True)

# %%
gk_data.head()
# Out:
#       Pos      Name   BV   SV         Team  27_xMins  27_Pts
# index
# 7       G      Leno  5.0  5.0      Arsenal        88   4.059
# 11      G  Martínez  5.3  4.9  Aston Villa        89   3.755
# 27      G    Heaton  4.5  4.5  Aston Villa         0   0.000
# 31      G     Steer  3.9  3.9  Aston Villa         0   0.000
# 34      G    Nyland  4.0  4.0  Aston Villa         0   0.000

# %%
players = gk_data.index.tolist()

# %%
players
# Out:
# [7,
#  11,
#  27,
#  31,
#  34,
#  55,
#  69,
#  95,
#  98,
#  100,
#  111,
#  125,
#  127,
#  150,
#  156,
#  166,
#  170,
#  182,
#  185,
#  193,
#  207,
#  212,
#  216,
#  222,
#  244,
#  251,
#  266,
#  277,
#  288,
#  290,
#  304,
#  324,
#  325,
#  347,
#  349,
#  362,
#  370,
#  382,
#  392,
#  416,
#  428,
#  429,
#  430,
#  432,
#  452,
#  454,
#  471,
#  481,
#  482,
#  487,
#  502,
#  515,
#  522,
#  526,
#  527,
#  531,
#  537,
#  546,
#  547,
#  559,
#  572,
#  577,
#  579,
#  582,
#  585,
#  592,
#  594,
#  596,
#  603,
#  605,
#  607,
#  616,
#  624,
#  638,
#  661]

# %%
lineup = model.add_variables(players, name='lineup', vartype=so.binary)

# %%
lineup[7]
# Out:
# sasoptpy.Variable(name='lineup[7]', lb=0, ub=1, vartype='BIN')

# %%
bench = model.add_variables(players, name='bench', vartype=so.binary)

# %%
total_xp = so.expr_sum(lineup[p] * gk_data.loc[p,'27_Pts'] for p in players) + 0.1 * so.expr_sum(bench[p] * gk_data.loc[p, '27_Pts'] for p in players)

# %%
total_xp
# Out:
# sasoptpy.Expression(exp = 4.059 * lineup[7] + 3.755 * lineup[11] + 3.279 * lineup[95] + 0.508 * lineup[111] + 3.083 * lineup[127] + 3.221 * lineup[156] + 3.361 * lineup[212] + 3.549 * lineup[216] + 3.418 * lineup[251] + 8.444 * lineup[277] + 3.12 * lineup[304] + 2.199 * lineup[324] + 0.163 * lineup[325] + 0.794 * lineup[362] + 4.254 * lineup[382] + 3.762 * lineup[416] + 0.078 * lineup[428] + 0.688 * lineup[429] + 2.682 * lineup[430] + 3.546 * lineup[454] + 3.431 * lineup[482] + 3.113 * lineup[515] + 6.424 * lineup[522] + 3.916 * lineup[547] + 3.712 * lineup[596] + 0.035 * lineup[603] + 0.4059 * bench[7] + 0.3755 * bench[11] + 0.3279 * bench[95] + 0.0508 * bench[111] + 0.3083 * bench[127] + 0.3221 * bench[156] + 0.3361 * bench[212] + 0.3549 * bench[216] + 0.3418 * bench[251] + 0.8444 * bench[277] + 0.312 * bench[304] + 0.2199 * bench[324] + 0.0163 * bench[325] + 0.0794 * bench[362] + 0.4254 * bench[382] + 0.3762 * bench[416] + 0.0078 * bench[428] + 0.0688 * bench[429] + 0.2682 * bench[430] + 0.3546 * bench[454] + 0.3431 * bench[482] + 0.3113 * bench[515] + 0.6424 * bench[522] + 0.3916 * bench[547] + 0.3712 * bench[596] + 0.0035 * bench[603], name=None)

# %%
model.set_objective(total_xp, name='total_xp_obj', sense=so.maximize)
# Out:
# sasoptpy.Expression(exp = 4.059 * lineup[7] + 3.755 * lineup[11] + 3.279 * lineup[95] + 0.508 * lineup[111] + 3.083 * lineup[127] + 3.221 * lineup[156] + 3.361 * lineup[212] + 3.549 * lineup[216] + 3.418 * lineup[251] + 8.444 * lineup[277] + 3.12 * lineup[304] + 2.199 * lineup[324] + 0.163 * lineup[325] + 0.794 * lineup[362] + 4.254 * lineup[382] + 3.762 * lineup[416] + 0.078 * lineup[428] + 0.688 * lineup[429] + 2.682 * lineup[430] + 3.546 * lineup[454] + 3.431 * lineup[482] + 3.113 * lineup[515] + 6.424 * lineup[522] + 3.916 * lineup[547] + 3.712 * lineup[596] + 0.035 * lineup[603] + 0.4059 * bench[7] + 0.3755 * bench[11] + 0.3279 * bench[95] + 0.0508 * bench[111] + 0.3083 * bench[127] + 0.3221 * bench[156] + 0.3361 * bench[212] + 0.3549 * bench[216] + 0.3418 * bench[251] + 0.8444 * bench[277] + 0.312 * bench[304] + 0.2199 * bench[324] + 0.0163 * bench[325] + 0.0794 * bench[362] + 0.4254 * bench[382] + 0.3762 * bench[416] + 0.0078 * bench[428] + 0.0688 * bench[429] + 0.2682 * bench[430] + 0.3546 * bench[454] + 0.3431 * bench[482] + 0.3113 * bench[515] + 0.6424 * bench[522] + 0.3916 * bench[547] + 0.3712 * bench[596] + 0.0035 * bench[603], name='total_xp_obj')

# %%
model.add_constraints((lineup[p] + bench[p] <= 1 for p in players), name='lineup_or_bench');

# %%
model.add_constraint(so.expr_sum(lineup[p] for p in players) == 1, name='single_lineup');

# %%
model.add_constraint(so.expr_sum(bench[p] for p in players) == 1, name='single_bench')
# Out:
# sasoptpy.Constraint(bench[7] + bench[11] + bench[27] + bench[31] + bench[34] + bench[55] + bench[69] + bench[95] + bench[98] + bench[100] + bench[111] + bench[125] + bench[127] + bench[150] + bench[156] + bench[166] + bench[170] + bench[182] + bench[185] + bench[193] + bench[207] + bench[212] + bench[216] + bench[222] + bench[244] + bench[251] + bench[266] + bench[277] + bench[288] + bench[290] + bench[304] + bench[324] + bench[325] + bench[347] + bench[349] + bench[362] + bench[370] + bench[382] + bench[392] + bench[416] + bench[428] + bench[429] + bench[430] + bench[432] + bench[452] + bench[454] + bench[471] + bench[481] + bench[482] + bench[487] + bench[502] + bench[515] + bench[522] + bench[526] + bench[527] + bench[531] + bench[537] + bench[546] + bench[547] + bench[559] + bench[572] + bench[577] + bench[579] + bench[582] + bench[585] + bench[592] + bench[594] + bench[596] + bench[603] + bench[605] + bench[607] + bench[616] + bench[624] + bench[638] + bench[661] ==  1, name='single_bench')

# %%
budget = 9.2
model.add_constraint(so.expr_sum((lineup[p] + bench[p]) * gk_data.loc[p, 'BV'] for p in players) <= budget, name='budget_con')
# Out:
# sasoptpy.Constraint(5.0 * lineup[7] + 5.0 * bench[7] + 5.3 * lineup[11] + 5.3 * bench[11] + 4.5 * lineup[27] + 4.5 * bench[27] + 3.9 * lineup[31] + 3.9 * bench[31] + 4.0 * lineup[34] + 4.0 * bench[34] + 4.0 * lineup[55] + 4.0 * bench[55] + 4.2 * lineup[69] + 4.2 * bench[69] + 5.6 * lineup[95] + 5.6 * bench[95] + 4.0 * lineup[98] + 4.0 * bench[98] + 4.6 * lineup[100] + 4.6 * bench[100] + 4.7 * lineup[111] + 4.7 * bench[111] + 4.3 * lineup[125] + 4.3 * bench[125] + 4.8 * lineup[127] + 4.8 * bench[127] + 4.3 * lineup[150] + 4.3 * bench[150] + 4.8 * lineup[156] + 4.8 * bench[156] + 4.3 * lineup[166] + 4.3 * bench[166] + 3.9 * lineup[170] + 3.9 * bench[170] + 4.3 * lineup[182] + 4.3 * bench[182] + 4.3 * lineup[185] + 4.3 * bench[185] + 4.2 * lineup[193] + 4.2 * bench[193] + 4.0 * lineup[207] + 4.0 * bench[207] + 4.6 * lineup[212] + 4.6 * bench[212] + 5.5 * lineup[216] + 5.5 * bench[216] + 4.3 * lineup[222] + 4.3 * bench[222] + 4.2 * lineup[244] + 4.2 * bench[244] + 5.9 * lineup[251] + 5.9 * bench[251] + 4.5 * lineup[266] + 4.5 * bench[266] + 6.1 * lineup[277] + 6.1 * bench[277] + 4.9 * lineup[288] + 4.9 * bench[288] + 5.3 * lineup[290] + 5.3 * bench[290] + 5.2 * lineup[304] + 5.2 * bench[304] + 5.0 * lineup[324] + 5.0 * bench[324] + 4.8 * lineup[325] + 4.8 * bench[325] + 4.3 * lineup[347] + 4.3 * bench[347] + 4.3 * lineup[349] + 4.3 * bench[349] + 4.5 * lineup[362] + 4.5 * bench[362] + 4.3 * lineup[370] + 4.3 * bench[370] + 5.6 * lineup[382] + 5.6 * bench[382] + 4.3 * lineup[392] + 4.3 * bench[392] + 4.5 * lineup[416] + 4.5 * bench[416] + 4.0 * lineup[428] + 4.0 * bench[428] + 4.3 * lineup[429] + 4.3 * bench[429] + 5.0 * lineup[430] + 5.0 * bench[430] + 4.5 * lineup[432] + 4.5 * bench[432] + 4.3 * lineup[452] + 4.3 * bench[452] + 5.3 * lineup[454] + 5.3 * bench[454] + 4.4 * lineup[471] + 4.4 * bench[471] + 4.3 * lineup[481] + 4.3 * bench[481] + 4.6 * lineup[482] + 4.6 * bench[482] + 4.3 * lineup[487] + 4.3 * bench[487] + 4.0 * lineup[502] + 4.0 * bench[502] + 4.5 * lineup[515] + 4.5 * bench[515] + 4.0 * lineup[522] + 4.0 * bench[522] + 4.0 * lineup[526] + 4.0 * bench[526] + 3.9 * lineup[527] + 3.9 * bench[527] + 4.0 * lineup[531] + 4.0 * bench[531] + 4.4 * lineup[537] + 4.4 * bench[537] + 4.4 * lineup[546] + 4.4 * bench[546] + 5.1 * lineup[547] + 5.1 * bench[547] + 4.5 * lineup[559] + 4.5 * bench[559] + 4.5 * lineup[572] + 4.5 * bench[572] + 4.0 * lineup[577] + 4.0 * bench[577] + 4.0 * lineup[579] + 4.0 * bench[579] + 4.0 * lineup[582] + 4.0 * bench[582] + 4.5 * lineup[585] + 4.5 * bench[585] + 4.0 * lineup[592] + 4.0 * bench[592] + 4.0 * lineup[594] + 4.0 * bench[594] + 4.5 * lineup[596] + 4.5 * bench[596] + 4.0 * lineup[603] + 4.0 * bench[603] + 4.0 * lineup[605] + 4.0 * bench[605] + 3.9 * lineup[607] + 3.9 * bench[607] + 4.0 * lineup[616] + 4.0 * bench[616] + 4.0 * lineup[624] + 4.0 * bench[624] + 4.0 * lineup[638] + 4.0 * bench[638] + 3.9 * lineup[661] + 3.9 * bench[661] <=  9.2, name='budget_con')

# %%
print(model.export_mps(fetch=True))
# Out:
# NAME     gk_model
# ROWS
#  MAX     total_xp_obj
#  L       lineup_or_bench[7]
#  L       lineup_or_bench[11]
#  L       lineup_or_bench[27]
#  L       lineup_or_bench[31]
#  L       lineup_or_bench[34]
#  L       lineup_or_bench[55]
#  L       lineup_or_bench[69]
#  L       lineup_or_bench[95]
#  L       lineup_or_bench[98]
#  L       lineup_or_bench[100]
#  L       lineup_or_bench[111]
#  L       lineup_or_bench[125]
#  L       lineup_or_bench[127]
#  L       lineup_or_bench[150]
#  L       lineup_or_bench[156]
#  L       lineup_or_bench[166]
#  L       lineup_or_bench[170]
#  L       lineup_or_bench[182]
#  L       lineup_or_bench[185]
#  L       lineup_or_bench[193]
#  L       lineup_or_bench[207]
#  L       lineup_or_bench[212]
#  L       lineup_or_bench[216]
#  L       lineup_or_bench[222]
#  L       lineup_or_bench[244]
#  L       lineup_or_bench[251]
#  L       lineup_or_bench[266]
#  L       lineup_or_bench[277]
#  L       lineup_or_bench[288]
#  L       lineup_or_bench[290]
#  L       lineup_or_bench[304]
#  L       lineup_or_bench[324]
#  L       lineup_or_bench[325]
#  L       lineup_or_bench[347]
#  L       lineup_or_bench[349]
#  L       lineup_or_bench[362]
#  L       lineup_or_bench[370]
#  L       lineup_or_bench[382]
#  L       lineup_or_bench[392]
#  L       lineup_or_bench[416]
#  L       lineup_or_bench[428]
#  L       lineup_or_bench[429]
#  L       lineup_or_bench[430]
#  L       lineup_or_bench[432]
#  L       lineup_or_bench[452]
#  L       lineup_or_bench[454]
#  L       lineup_or_bench[471]
#  L       lineup_or_bench[481]
#  L       lineup_or_bench[482]
#  L       lineup_or_bench[487]
#  L       lineup_or_bench[502]
#  L       lineup_or_bench[515]
#  L       lineup_or_bench[522]
#  L       lineup_or_bench[526]
#  L       lineup_or_bench[527]
#  L       lineup_or_bench[531]
#  L       lineup_or_bench[537]
#  L       lineup_or_bench[546]
#  L       lineup_or_bench[547]
#  L       lineup_or_bench[559]
#  L       lineup_or_bench[572]
#  L       lineup_or_bench[577]
#  L       lineup_or_bench[579]
#  L       lineup_or_bench[582]
#  L       lineup_or_bench[585]
#  L       lineup_or_bench[592]
#  L       lineup_or_bench[594]
#  L       lineup_or_bench[596]
#  L       lineup_or_bench[603]
#  L       lineup_or_bench[605]
#  L       lineup_or_bench[607]
#  L       lineup_or_bench[616]
#  L       lineup_or_bench[624]
#  L       lineup_or_bench[638]
#  L       lineup_or_bench[661]
#  E       single_lineup
#  E       single_bench
#  L       budget_con
# COLUMNS
#          lineup[7]             total_xp_obj          4.0590  lineup_or_bench[7]    1.0
#          lineup[7]             single_lineup         1.0000  budget_con            5.0
#          lineup[11]            total_xp_obj          3.7550  lineup_or_bench[11]   1.0
#          lineup[11]            single_lineup         1.0000  budget_con            5.3
#          lineup[27]            lineup_or_bench[27]   1.0000  single_lineup         1.0
#          lineup[27]            budget_con            4.5000
#          lineup[31]            lineup_or_bench[31]   1.0000  single_lineup         1.0
#          lineup[31]            budget_con            3.9000
#          lineup[34]            lineup_or_bench[34]   1.0000  single_lineup         1.0
#          lineup[34]            budget_con            4.0000
#          lineup[55]            lineup_or_bench[55]   1.0000  single_lineup         1.0
#          lineup[55]            budget_con            4.0000
#          lineup[69]            lineup_or_bench[69]   1.0000  single_lineup         1.0
#          lineup[69]            budget_con            4.2000
#          lineup[95]            total_xp_obj          3.2790  lineup_or_bench[95]   1.0
#          lineup[95]            single_lineup         1.0000  budget_con            5.6
#          lineup[98]            lineup_or_bench[98]   1.0000  single_lineup         1.0
#          lineup[98]            budget_con            4.0000
#          lineup[100]           lineup_or_bench[100]  1.0000  single_lineup         1.0
#          lineup[100]           budget_con            4.6000
#          lineup[111]           total_xp_obj          0.5080  lineup_or_bench[111]  1.0
#          lineup[111]           single_lineup         1.0000  budget_con            4.7
#          lineup[125]           lineup_or_bench[125]  1.0000  single_lineup         1.0
#          lineup[125]           budget_con            4.3000
#          lineup[127]           total_xp_obj          3.0830  lineup_or_bench[127]  1.0
#          lineup[127]           single_lineup         1.0000  budget_con            4.8
#          lineup[150]           lineup_or_bench[150]  1.0000  single_lineup         1.0
#          lineup[150]           budget_con            4.3000
#          lineup[156]           total_xp_obj          3.2210  lineup_or_bench[156]  1.0
#          lineup[156]           single_lineup         1.0000  budget_con            4.8
#          lineup[166]           lineup_or_bench[166]  1.0000  single_lineup         1.0
#          lineup[166]           budget_con            4.3000
#          lineup[170]           lineup_or_bench[170]  1.0000  single_lineup         1.0
#          lineup[170]           budget_con            3.9000
#          lineup[182]           lineup_or_bench[182]  1.0000  single_lineup         1.0
#          lineup[182]           budget_con            4.3000
#          lineup[185]           lineup_or_bench[185]  1.0000  single_lineup         1.0
#          lineup[185]           budget_con            4.3000
#          lineup[193]           lineup_or_bench[193]  1.0000  single_lineup         1.0
#          lineup[193]           budget_con            4.2000
#          lineup[207]           lineup_or_bench[207]  1.0000  single_lineup         1.0
#          lineup[207]           budget_con            4.0000
#          lineup[212]           total_xp_obj          3.3610  lineup_or_bench[212]  1.0
#          lineup[212]           single_lineup         1.0000  budget_con            4.6
#          lineup[216]           total_xp_obj          3.5490  lineup_or_bench[216]  1.0
#          lineup[216]           single_lineup         1.0000  budget_con            5.5
#          lineup[222]           lineup_or_bench[222]  1.0000  single_lineup         1.0
#          lineup[222]           budget_con            4.3000
#          lineup[244]           lineup_or_bench[244]  1.0000  single_lineup         1.0
#          lineup[244]           budget_con            4.2000
#          lineup[251]           total_xp_obj          3.4180  lineup_or_bench[251]  1.0
#          lineup[251]           single_lineup         1.0000  budget_con            5.9
#          lineup[266]           lineup_or_bench[266]  1.0000  single_lineup         1.0
#          lineup[266]           budget_con            4.5000
#          lineup[277]           total_xp_obj          8.4440  lineup_or_bench[277]  1.0
#          lineup[277]           single_lineup         1.0000  budget_con            6.1
#          lineup[288]           lineup_or_bench[288]  1.0000  single_lineup         1.0
#          lineup[288]           budget_con            4.9000
#          lineup[290]           lineup_or_bench[290]  1.0000  single_lineup         1.0
#          lineup[290]           budget_con            5.3000
#          lineup[304]           total_xp_obj          3.1200  lineup_or_bench[304]  1.0
#          lineup[304]           single_lineup         1.0000  budget_con            5.2
#          lineup[324]           total_xp_obj          2.1990  lineup_or_bench[324]  1.0
#          lineup[324]           single_lineup         1.0000  budget_con            5.0
#          lineup[325]           total_xp_obj          0.1630  lineup_or_bench[325]  1.0
#          lineup[325]           single_lineup         1.0000  budget_con            4.8
#          lineup[347]           lineup_or_bench[347]  1.0000  single_lineup         1.0
#          lineup[347]           budget_con            4.3000
#          lineup[349]           lineup_or_bench[349]  1.0000  single_lineup         1.0
#          lineup[349]           budget_con            4.3000
#          lineup[362]           total_xp_obj          0.7940  lineup_or_bench[362]  1.0
#          lineup[362]           single_lineup         1.0000  budget_con            4.5
#          lineup[370]           lineup_or_bench[370]  1.0000  single_lineup         1.0
#          lineup[370]           budget_con            4.3000
#          lineup[382]           total_xp_obj          4.2540  lineup_or_bench[382]  1.0
#          lineup[382]           single_lineup         1.0000  budget_con            5.6
#          lineup[392]           lineup_or_bench[392]  1.0000  single_lineup         1.0
#          lineup[392]           budget_con            4.3000
#          lineup[416]           total_xp_obj          3.7620  lineup_or_bench[416]  1.0
#          lineup[416]           single_lineup         1.0000  budget_con            4.5
#          lineup[428]           total_xp_obj          0.0780  lineup_or_bench[428]  1.0
#          lineup[428]           single_lineup         1.0000  budget_con            4.0
#          lineup[429]           total_xp_obj          0.6880  lineup_or_bench[429]  1.0
#          lineup[429]           single_lineup         1.0000  budget_con            4.3
#          lineup[430]           total_xp_obj          2.6820  lineup_or_bench[430]  1.0
#          lineup[430]           single_lineup         1.0000  budget_con            5.0
#          lineup[432]           lineup_or_bench[432]  1.0000  single_lineup         1.0
#          lineup[432]           budget_con            4.5000
#          lineup[452]           lineup_or_bench[452]  1.0000  single_lineup         1.0
#          lineup[452]           budget_con            4.3000
#          lineup[454]           total_xp_obj          3.5460  lineup_or_bench[454]  1.0
#          lineup[454]           single_lineup         1.0000  budget_con            5.3
#          lineup[471]           lineup_or_bench[471]  1.0000  single_lineup         1.0
#          lineup[471]           budget_con            4.4000
#          lineup[481]           lineup_or_bench[481]  1.0000  single_lineup         1.0
#          lineup[481]           budget_con            4.3000
#          lineup[482]           total_xp_obj          3.4310  lineup_or_bench[482]  1.0
#          lineup[482]           single_lineup         1.0000  budget_con            4.6
#          lineup[487]           lineup_or_bench[487]  1.0000  single_lineup         1.0
#          lineup[487]           budget_con            4.3000
#          lineup[502]           lineup_or_bench[502]  1.0000  single_lineup         1.0
#          lineup[502]           budget_con            4.0000
#          lineup[515]           total_xp_obj          3.1130  lineup_or_bench[515]  1.0
#          lineup[515]           single_lineup         1.0000  budget_con            4.5
#          lineup[522]           total_xp_obj          6.4240  lineup_or_bench[522]  1.0
#          lineup[522]           single_lineup         1.0000  budget_con            4.0
#          lineup[526]           lineup_or_bench[526]  1.0000  single_lineup         1.0
#          lineup[526]           budget_con            4.0000
#          lineup[527]           lineup_or_bench[527]  1.0000  single_lineup         1.0
#          lineup[527]           budget_con            3.9000
#          lineup[531]           lineup_or_bench[531]  1.0000  single_lineup         1.0
#          lineup[531]           budget_con            4.0000
#          lineup[537]           lineup_or_bench[537]  1.0000  single_lineup         1.0
#          lineup[537]           budget_con            4.4000
#          lineup[546]           lineup_or_bench[546]  1.0000  single_lineup         1.0
#          lineup[546]           budget_con            4.4000
#          lineup[547]           total_xp_obj          3.9160  lineup_or_bench[547]  1.0
#          lineup[547]           single_lineup         1.0000  budget_con            5.1
#          lineup[559]           lineup_or_bench[559]  1.0000  single_lineup         1.0
#          lineup[559]           budget_con            4.5000
#          lineup[572]           lineup_or_bench[572]  1.0000  single_lineup         1.0
#          lineup[572]           budget_con            4.5000
#          lineup[577]           lineup_or_bench[577]  1.0000  single_lineup         1.0
#          lineup[577]           budget_con            4.0000
#          lineup[579]           lineup_or_bench[579]  1.0000  single_lineup         1.0
#          lineup[579]           budget_con            4.0000
#          lineup[582]           lineup_or_bench[582]  1.0000  single_lineup         1.0
#          lineup[582]           budget_con            4.0000
#          lineup[585]           lineup_or_bench[585]  1.0000  single_lineup         1.0
#          lineup[585]           budget_con            4.5000
#          lineup[592]           lineup_or_bench[592]  1.0000  single_lineup         1.0
#          lineup[592]           budget_con            4.0000
#          lineup[594]           lineup_or_bench[594]  1.0000  single_lineup         1.0
#          lineup[594]           budget_con            4.0000
#          lineup[596]           total_xp_obj          3.7120  lineup_or_bench[596]  1.0
#          lineup[596]           single_lineup         1.0000  budget_con            4.5
#          lineup[603]           total_xp_obj          0.0350  lineup_or_bench[603]  1.0
#          lineup[603]           single_lineup         1.0000  budget_con            4.0
#          lineup[605]           lineup_or_bench[605]  1.0000  single_lineup         1.0
#          lineup[605]           budget_con            4.0000
#          lineup[607]           lineup_or_bench[607]  1.0000  single_lineup         1.0
#          lineup[607]           budget_con            3.9000
#          lineup[616]           lineup_or_bench[616]  1.0000  single_lineup         1.0
#          lineup[616]           budget_con            4.0000
#          lineup[624]           lineup_or_bench[624]  1.0000  single_lineup         1.0
#          lineup[624]           budget_con            4.0000
#          lineup[638]           lineup_or_bench[638]  1.0000  single_lineup         1.0
#          lineup[638]           budget_con            4.0000
#          lineup[661]           lineup_or_bench[661]  1.0000  single_lineup         1.0
#          lineup[661]           budget_con            3.9000
#          bench[7]              total_xp_obj          0.4059  lineup_or_bench[7]    1.0
#          bench[7]              single_bench          1.0000  budget_con            5.0
#          bench[11]             total_xp_obj          0.3755  lineup_or_bench[11]   1.0
#          bench[11]             single_bench          1.0000  budget_con            5.3
#          bench[27]             lineup_or_bench[27]   1.0000  single_bench          1.0
#          bench[27]             budget_con            4.5000
#          bench[31]             lineup_or_bench[31]   1.0000  single_bench          1.0
#          bench[31]             budget_con            3.9000
#          bench[34]             lineup_or_bench[34]   1.0000  single_bench          1.0
#          bench[34]             budget_con            4.0000
#          bench[55]             lineup_or_bench[55]   1.0000  single_bench          1.0
#          bench[55]             budget_con            4.0000
#          bench[69]             lineup_or_bench[69]   1.0000  single_bench          1.0
#          bench[69]             budget_con            4.2000
#          bench[95]             total_xp_obj          0.3279  lineup_or_bench[95]   1.0
#          bench[95]             single_bench          1.0000  budget_con            5.6
#          bench[98]             lineup_or_bench[98]   1.0000  single_bench          1.0
#          bench[98]             budget_con            4.0000
#          bench[100]            lineup_or_bench[100]  1.0000  single_bench          1.0
#          bench[100]            budget_con            4.6000
#          bench[111]            total_xp_obj          0.0508  lineup_or_bench[111]  1.0
#          bench[111]            single_bench          1.0000  budget_con            4.7
#          bench[125]            lineup_or_bench[125]  1.0000  single_bench          1.0
#          bench[125]            budget_con            4.3000
#          bench[127]            total_xp_obj          0.3083  lineup_or_bench[127]  1.0
#          bench[127]            single_bench          1.0000  budget_con            4.8
#          bench[150]            lineup_or_bench[150]  1.0000  single_bench          1.0
#          bench[150]            budget_con            4.3000
#          bench[156]            total_xp_obj          0.3221  lineup_or_bench[156]  1.0
#          bench[156]            single_bench          1.0000  budget_con            4.8
#          bench[166]            lineup_or_bench[166]  1.0000  single_bench          1.0
#          bench[166]            budget_con            4.3000
#          bench[170]            lineup_or_bench[170]  1.0000  single_bench          1.0
#          bench[170]            budget_con            3.9000
#          bench[182]            lineup_or_bench[182]  1.0000  single_bench          1.0
#          bench[182]            budget_con            4.3000
#          bench[185]            lineup_or_bench[185]  1.0000  single_bench          1.0
#          bench[185]            budget_con            4.3000
#          bench[193]            lineup_or_bench[193]  1.0000  single_bench          1.0
#          bench[193]            budget_con            4.2000
#          bench[207]            lineup_or_bench[207]  1.0000  single_bench          1.0
#          bench[207]            budget_con            4.0000
#          bench[212]            total_xp_obj          0.3361  lineup_or_bench[212]  1.0
#          bench[212]            single_bench          1.0000  budget_con            4.6
#          bench[216]            total_xp_obj          0.3549  lineup_or_bench[216]  1.0
#          bench[216]            single_bench          1.0000  budget_con            5.5
#          bench[222]            lineup_or_bench[222]  1.0000  single_bench          1.0
#          bench[222]            budget_con            4.3000
#          bench[244]            lineup_or_bench[244]  1.0000  single_bench          1.0
#          bench[244]            budget_con            4.2000
#          bench[251]            total_xp_obj          0.3418  lineup_or_bench[251]  1.0
#          bench[251]            single_bench          1.0000  budget_con            5.9
#          bench[266]            lineup_or_bench[266]  1.0000  single_bench          1.0
#          bench[266]            budget_con            4.5000
#          bench[277]            total_xp_obj          0.8444  lineup_or_bench[277]  1.0
#          bench[277]            single_bench          1.0000  budget_con            6.1
#          bench[288]            lineup_or_bench[288]  1.0000  single_bench          1.0
#          bench[288]            budget_con            4.9000
#          bench[290]            lineup_or_bench[290]  1.0000  single_bench          1.0
#          bench[290]            budget_con            5.3000
#          bench[304]            total_xp_obj          0.3120  lineup_or_bench[304]  1.0
#          bench[304]            single_bench          1.0000  budget_con            5.2
#          bench[324]            total_xp_obj          0.2199  lineup_or_bench[324]  1.0
#          bench[324]            single_bench          1.0000  budget_con            5.0
#          bench[325]            total_xp_obj          0.0163  lineup_or_bench[325]  1.0
#          bench[325]            single_bench          1.0000  budget_con            4.8
#          bench[347]            lineup_or_bench[347]  1.0000  single_bench          1.0
#          bench[347]            budget_con            4.3000
#          bench[349]            lineup_or_bench[349]  1.0000  single_bench          1.0
#          bench[349]            budget_con            4.3000
#          bench[362]            total_xp_obj          0.0794  lineup_or_bench[362]  1.0
#          bench[362]            single_bench          1.0000  budget_con            4.5
#          bench[370]            lineup_or_bench[370]  1.0000  single_bench          1.0
#          bench[370]            budget_con            4.3000
#          bench[382]            total_xp_obj          0.4254  lineup_or_bench[382]  1.0
#          bench[382]            single_bench          1.0000  budget_con            5.6
#          bench[392]            lineup_or_bench[392]  1.0000  single_bench          1.0
#          bench[392]            budget_con            4.3000
#          bench[416]            total_xp_obj          0.3762  lineup_or_bench[416]  1.0
#          bench[416]            single_bench          1.0000  budget_con            4.5
#          bench[428]            total_xp_obj          0.0078  lineup_or_bench[428]  1.0
#          bench[428]            single_bench          1.0000  budget_con            4.0
#          bench[429]            total_xp_obj          0.0688  lineup_or_bench[429]  1.0
#          bench[429]            single_bench          1.0000  budget_con            4.3
#          bench[430]            total_xp_obj          0.2682  lineup_or_bench[430]  1.0
#          bench[430]            single_bench          1.0000  budget_con            5.0
#          bench[432]            lineup_or_bench[432]  1.0000  single_bench          1.0
#          bench[432]            budget_con            4.5000
#          bench[452]            lineup_or_bench[452]  1.0000  single_bench          1.0
#          bench[452]            budget_con            4.3000
#          bench[454]            total_xp_obj          0.3546  lineup_or_bench[454]  1.0
#          bench[454]            single_bench          1.0000  budget_con            5.3
#          bench[471]            lineup_or_bench[471]  1.0000  single_bench          1.0
#          bench[471]            budget_con            4.4000
#          bench[481]            lineup_or_bench[481]  1.0000  single_bench          1.0
#          bench[481]            budget_con            4.3000
#          bench[482]            total_xp_obj          0.3431  lineup_or_bench[482]  1.0
#          bench[482]            single_bench          1.0000  budget_con            4.6
#          bench[487]            lineup_or_bench[487]  1.0000  single_bench          1.0
#          bench[487]            budget_con            4.3000
#          bench[502]            lineup_or_bench[502]  1.0000  single_bench          1.0
#          bench[502]            budget_con            4.0000
#          bench[515]            total_xp_obj          0.3113  lineup_or_bench[515]  1.0
#          bench[515]            single_bench          1.0000  budget_con            4.5
#          bench[522]            total_xp_obj          0.6424  lineup_or_bench[522]  1.0
#          bench[522]            single_bench          1.0000  budget_con            4.0
#          bench[526]            lineup_or_bench[526]  1.0000  single_bench          1.0
#          bench[526]            budget_con            4.0000
#          bench[527]            lineup_or_bench[527]  1.0000  single_bench          1.0
#          bench[527]            budget_con            3.9000
#          bench[531]            lineup_or_bench[531]  1.0000  single_bench          1.0
#          bench[531]            budget_con            4.0000
#          bench[537]            lineup_or_bench[537]  1.0000  single_bench          1.0
#          bench[537]            budget_con            4.4000
#          bench[546]            lineup_or_bench[546]  1.0000  single_bench          1.0
#          bench[546]            budget_con            4.4000
#          bench[547]            total_xp_obj          0.3916  lineup_or_bench[547]  1.0
#          bench[547]            single_bench          1.0000  budget_con            5.1
#          bench[559]            lineup_or_bench[559]  1.0000  single_bench          1.0
#          bench[559]            budget_con            4.5000
#          bench[572]            lineup_or_bench[572]  1.0000  single_bench          1.0
#          bench[572]            budget_con            4.5000
#          bench[577]            lineup_or_bench[577]  1.0000  single_bench          1.0
#          bench[577]            budget_con            4.0000
#          bench[579]            lineup_or_bench[579]  1.0000  single_bench          1.0
#          bench[579]            budget_con            4.0000
#          bench[582]            lineup_or_bench[582]  1.0000  single_bench          1.0
#          bench[582]            budget_con            4.0000
#          bench[585]            lineup_or_bench[585]  1.0000  single_bench          1.0
#          bench[585]            budget_con            4.5000
#          bench[592]            lineup_or_bench[592]  1.0000  single_bench          1.0
#          bench[592]            budget_con            4.0000
#          bench[594]            lineup_or_bench[594]  1.0000  single_bench          1.0
#          bench[594]            budget_con            4.0000
#          bench[596]            total_xp_obj          0.3712  lineup_or_bench[596]  1.0
#          bench[596]            single_bench          1.0000  budget_con            4.5
#          bench[603]            total_xp_obj          0.0035  lineup_or_bench[603]  1.0
#          bench[603]            single_bench          1.0000  budget_con            4.0
#          bench[605]            lineup_or_bench[605]  1.0000  single_bench          1.0
#          bench[605]            budget_con            4.0000
#          bench[607]            lineup_or_bench[607]  1.0000  single_bench          1.0
#          bench[607]            budget_con            3.9000
#          bench[616]            lineup_or_bench[616]  1.0000  single_bench          1.0
#          bench[616]            budget_con            4.0000
#          bench[624]            lineup_or_bench[624]  1.0000  single_bench          1.0
#          bench[624]            budget_con            4.0000
#          bench[638]            lineup_or_bench[638]  1.0000  single_bench          1.0
#          bench[638]            budget_con            4.0000
#          bench[661]            lineup_or_bench[661]  1.0000  single_bench          1.0
#          bench[661]            budget_con            3.9000
# RHS
#          RHS                   lineup_or_bench[7]    1.0000  lineup_or_bench[11]   1.0
#          RHS                   lineup_or_bench[27]   1.0000  lineup_or_bench[31]   1.0
#          RHS                   lineup_or_bench[34]   1.0000  lineup_or_bench[55]   1.0
#          RHS                   lineup_or_bench[69]   1.0000  lineup_or_bench[95]   1.0
#          RHS                   lineup_or_bench[98]   1.0000  lineup_or_bench[100]  1.0
#          RHS                   lineup_or_bench[111]  1.0000  lineup_or_bench[125]  1.0
#          RHS                   lineup_or_bench[127]  1.0000  lineup_or_bench[150]  1.0
#          RHS                   lineup_or_bench[156]  1.0000  lineup_or_bench[166]  1.0
#          RHS                   lineup_or_bench[170]  1.0000  lineup_or_bench[182]  1.0
#          RHS                   lineup_or_bench[185]  1.0000  lineup_or_bench[193]  1.0
#          RHS                   lineup_or_bench[207]  1.0000  lineup_or_bench[212]  1.0
#          RHS                   lineup_or_bench[216]  1.0000  lineup_or_bench[222]  1.0
#          RHS                   lineup_or_bench[244]  1.0000  lineup_or_bench[251]  1.0
#          RHS                   lineup_or_bench[266]  1.0000  lineup_or_bench[277]  1.0
#          RHS                   lineup_or_bench[288]  1.0000  lineup_or_bench[290]  1.0
#          RHS                   lineup_or_bench[304]  1.0000  lineup_or_bench[324]  1.0
#          RHS                   lineup_or_bench[325]  1.0000  lineup_or_bench[347]  1.0
#          RHS                   lineup_or_bench[349]  1.0000  lineup_or_bench[362]  1.0
#          RHS                   lineup_or_bench[370]  1.0000  lineup_or_bench[382]  1.0
#          RHS                   lineup_or_bench[392]  1.0000  lineup_or_bench[416]  1.0
#          RHS                   lineup_or_bench[428]  1.0000  lineup_or_bench[429]  1.0
#          RHS                   lineup_or_bench[430]  1.0000  lineup_or_bench[432]  1.0
#          RHS                   lineup_or_bench[452]  1.0000  lineup_or_bench[454]  1.0
#          RHS                   lineup_or_bench[471]  1.0000  lineup_or_bench[481]  1.0
#          RHS                   lineup_or_bench[482]  1.0000  lineup_or_bench[487]  1.0
#          RHS                   lineup_or_bench[502]  1.0000  lineup_or_bench[515]  1.0
#          RHS                   lineup_or_bench[522]  1.0000  lineup_or_bench[526]  1.0
#          RHS                   lineup_or_bench[527]  1.0000  lineup_or_bench[531]  1.0
#          RHS                   lineup_or_bench[537]  1.0000  lineup_or_bench[546]  1.0
#          RHS                   lineup_or_bench[547]  1.0000  lineup_or_bench[559]  1.0
#          RHS                   lineup_or_bench[572]  1.0000  lineup_or_bench[577]  1.0
#          RHS                   lineup_or_bench[579]  1.0000  lineup_or_bench[582]  1.0
#          RHS                   lineup_or_bench[585]  1.0000  lineup_or_bench[592]  1.0
#          RHS                   lineup_or_bench[594]  1.0000  lineup_or_bench[596]  1.0
#          RHS                   lineup_or_bench[603]  1.0000  lineup_or_bench[605]  1.0
#          RHS                   lineup_or_bench[607]  1.0000  lineup_or_bench[616]  1.0
#          RHS                   lineup_or_bench[624]  1.0000  lineup_or_bench[638]  1.0
#          RHS                   lineup_or_bench[661]  1.0000  single_lineup         1.0
#          RHS                   single_bench          1.0000  budget_con            9.2
# RANGES
# BOUNDS
#  BV      BND                   lineup[7]             1.0000
#  BV      BND                   lineup[11]            1.0000
#  BV      BND                   lineup[27]            1.0000
#  BV      BND                   lineup[31]            1.0000
#  BV      BND                   lineup[34]            1.0000
#  BV      BND                   lineup[55]            1.0000
#  BV      BND                   lineup[69]            1.0000
#  BV      BND                   lineup[95]            1.0000
#  BV      BND                   lineup[98]            1.0000
#  BV      BND                   lineup[100]           1.0000
#  BV      BND                   lineup[111]           1.0000
#  BV      BND                   lineup[125]           1.0000
#  BV      BND                   lineup[127]           1.0000
#  BV      BND                   lineup[150]           1.0000
#  BV      BND                   lineup[156]           1.0000
#  BV      BND                   lineup[166]           1.0000
#  BV      BND                   lineup[170]           1.0000
#  BV      BND                   lineup[182]           1.0000
#  BV      BND                   lineup[185]           1.0000
#  BV      BND                   lineup[193]           1.0000
#  BV      BND                   lineup[207]           1.0000
#  BV      BND                   lineup[212]           1.0000
#  BV      BND                   lineup[216]           1.0000
#  BV      BND                   lineup[222]           1.0000
#  BV      BND                   lineup[244]           1.0000
#  BV      BND                   lineup[251]           1.0000
#  BV      BND                   lineup[266]           1.0000
#  BV      BND                   lineup[277]           1.0000
#  BV      BND                   lineup[288]           1.0000
#  BV      BND                   lineup[290]           1.0000
#  BV      BND                   lineup[304]           1.0000
#  BV      BND                   lineup[324]           1.0000
#  BV      BND                   lineup[325]           1.0000
#  BV      BND                   lineup[347]           1.0000
#  BV      BND                   lineup[349]           1.0000
#  BV      BND                   lineup[362]           1.0000
#  BV      BND                   lineup[370]           1.0000
#  BV      BND                   lineup[382]           1.0000
#  BV      BND                   lineup[392]           1.0000
#  BV      BND                   lineup[416]           1.0000
#  BV      BND                   lineup[428]           1.0000
#  BV      BND                   lineup[429]           1.0000
#  BV      BND                   lineup[430]           1.0000
#  BV      BND                   lineup[432]           1.0000
#  BV      BND                   lineup[452]           1.0000
#  BV      BND                   lineup[454]           1.0000
#  BV      BND                   lineup[471]           1.0000
#  BV      BND                   lineup[481]           1.0000
#  BV      BND                   lineup[482]           1.0000
#  BV      BND                   lineup[487]           1.0000
#  BV      BND                   lineup[502]           1.0000
#  BV      BND                   lineup[515]           1.0000
#  BV      BND                   lineup[522]           1.0000
#  BV      BND                   lineup[526]           1.0000
#  BV      BND                   lineup[527]           1.0000
#  BV      BND                   lineup[531]           1.0000
#  BV      BND                   lineup[537]           1.0000
#  BV      BND                   lineup[546]           1.0000
#  BV      BND                   lineup[547]           1.0000
#  BV      BND                   lineup[559]           1.0000
#  BV      BND                   lineup[572]           1.0000
#  BV      BND                   lineup[577]           1.0000
#  BV      BND                   lineup[579]           1.0000
#  BV      BND                   lineup[582]           1.0000
#  BV      BND                   lineup[585]           1.0000
#  BV      BND                   lineup[592]           1.0000
#  BV      BND                   lineup[594]           1.0000
#  BV      BND                   lineup[596]           1.0000
#  BV      BND                   lineup[603]           1.0000
#  BV      BND                   lineup[605]           1.0000
#  BV      BND                   lineup[607]           1.0000
#  BV      BND                   lineup[616]           1.0000
#  BV      BND                   lineup[624]           1.0000
#  BV      BND                   lineup[638]           1.0000
#  BV      BND                   lineup[661]           1.0000
#  BV      BND                   bench[7]              1.0000
#  BV      BND                   bench[11]             1.0000
#  BV      BND                   bench[27]             1.0000
#  BV      BND                   bench[31]             1.0000
#  BV      BND                   bench[34]             1.0000
#  BV      BND                   bench[55]             1.0000
#  BV      BND                   bench[69]             1.0000
#  BV      BND                   bench[95]             1.0000
#  BV      BND                   bench[98]             1.0000
#  BV      BND                   bench[100]            1.0000
#  BV      BND                   bench[111]            1.0000
#  BV      BND                   bench[125]            1.0000
#  BV      BND                   bench[127]            1.0000
#  BV      BND                   bench[150]            1.0000
#  BV      BND                   bench[156]            1.0000
#  BV      BND                   bench[166]            1.0000
#  BV      BND                   bench[170]            1.0000
#  BV      BND                   bench[182]            1.0000
#  BV      BND                   bench[185]            1.0000
#  BV      BND                   bench[193]            1.0000
#  BV      BND                   bench[207]            1.0000
#  BV      BND                   bench[212]            1.0000
#  BV      BND                   bench[216]            1.0000
#  BV      BND                   bench[222]            1.0000
#  BV      BND                   bench[244]            1.0000
#  BV      BND                   bench[251]            1.0000
#  BV      BND                   bench[266]            1.0000
#  BV      BND                   bench[277]            1.0000
#  BV      BND                   bench[288]            1.0000
#  BV      BND                   bench[290]            1.0000
#  BV      BND                   bench[304]            1.0000
#  BV      BND                   bench[324]            1.0000
#  BV      BND                   bench[325]            1.0000
#  BV      BND                   bench[347]            1.0000
#  BV      BND                   bench[349]            1.0000
#  BV      BND                   bench[362]            1.0000
#  BV      BND                   bench[370]            1.0000
#  BV      BND                   bench[382]            1.0000
#  BV      BND                   bench[392]            1.0000
#  BV      BND                   bench[416]            1.0000
#  BV      BND                   bench[428]            1.0000
#  BV      BND                   bench[429]            1.0000
#  BV      BND                   bench[430]            1.0000
#  BV      BND                   bench[432]            1.0000
#  BV      BND                   bench[452]            1.0000
#  BV      BND                   bench[454]            1.0000
#  BV      BND                   bench[471]            1.0000
#  BV      BND                   bench[481]            1.0000
#  BV      BND                   bench[482]            1.0000
#  BV      BND                   bench[487]            1.0000
#  BV      BND                   bench[502]            1.0000
#  BV      BND                   bench[515]            1.0000
#  BV      BND                   bench[522]            1.0000
#  BV      BND                   bench[526]            1.0000
#  BV      BND                   bench[527]            1.0000
#  BV      BND                   bench[531]            1.0000
#  BV      BND                   bench[537]            1.0000
#  BV      BND                   bench[546]            1.0000
#  BV      BND                   bench[547]            1.0000
#  BV      BND                   bench[559]            1.0000
#  BV      BND                   bench[572]            1.0000
#  BV      BND                   bench[577]            1.0000
#  BV      BND                   bench[579]            1.0000
#  BV      BND                   bench[582]            1.0000
#  BV      BND                   bench[585]            1.0000
#  BV      BND                   bench[592]            1.0000
#  BV      BND                   bench[594]            1.0000
#  BV      BND                   bench[596]            1.0000
#  BV      BND                   bench[603]            1.0000
#  BV      BND                   bench[605]            1.0000
#  BV      BND                   bench[607]            1.0000
#  BV      BND                   bench[616]            1.0000
#  BV      BND                   bench[624]            1.0000
#  BV      BND                   bench[638]            1.0000
#  BV      BND                   bench[661]            1.0000
# ENDATA

# %%
model.set_objective(-total_xp, name='total_xp_obj', sense='N')
# Out:
# sasoptpy.Expression(exp = - 4.059 * lineup[7] - 3.755 * lineup[11] - 3.279 * lineup[95] - 0.508 * lineup[111] - 3.083 * lineup[127] - 3.221 * lineup[156] - 3.361 * lineup[212] - 3.549 * lineup[216] - 3.418 * lineup[251] - 8.444 * lineup[277] - 3.12 * lineup[304] - 2.199 * lineup[324] - 0.163 * lineup[325] - 0.794 * lineup[362] - 4.254 * lineup[382] - 3.762 * lineup[416] - 0.078 * lineup[428] - 0.688 * lineup[429] - 2.682 * lineup[430] - 3.546 * lineup[454] - 3.431 * lineup[482] - 3.113 * lineup[515] - 6.424 * lineup[522] - 3.916 * lineup[547] - 3.712 * lineup[596] - 0.035 * lineup[603] - 0.4059 * bench[7] - 0.3755 * bench[11] - 0.3279 * bench[95] - 0.0508 * bench[111] - 0.3083 * bench[127] - 0.3221 * bench[156] - 0.3361 * bench[212] - 0.3549 * bench[216] - 0.3418 * bench[251] - 0.8444 * bench[277] - 0.312 * bench[304] - 0.2199 * bench[324] - 0.0163 * bench[325] - 0.0794 * bench[362] - 0.4254 * bench[382] - 0.3762 * bench[416] - 0.0078 * bench[428] - 0.0688 * bench[429] - 0.2682 * bench[430] - 0.3546 * bench[454] - 0.3431 * bench[482] - 0.3113 * bench[515] - 0.6424 * bench[522] - 0.3916 * bench[547] - 0.3712 * bench[596] - 0.0035 * bench[603], name='total_xp_obj')

# %%
model.export_mps(filename='gk.mps')

# %%
command = 'cbc gk.mps solve solu solution.txt'

# %%
# !{command}
# Out:
# Welcome to the CBC MILP Solver
# Version: devel
# Build Date: Feb 26 2021
#
# command line - cbc gk.mps solve solu solution.txt (default strategy 1)
# At line 1 NAME     gk_model
# At line 2 ROWS
# At line 82 COLUMNS
# At line 383 RHS
# At line 423 RANGES
# At line 424 BOUNDS
# At line 575 ENDATA
# Problem gk_model has 78 rows, 150 columns and 450 elements
# Coin0008I gk_model read with 0 errors
# Continuous objective value is -7.99724 - 0.00 seconds
# Cgl0005I 2 SOS with 150 members
# Cgl0004I processed model has 78 rows, 150 columns (150 integer (150 of which binary)) and 450 elements
# Coin3009W Conflict graph built in 0.003 seconds, density: 16.370%
# Cgl0015I Clique Strengthening extended 58 cliques, 75 were dominated
# After applying Clique Strengthening continuous objective value is -7.67
# Cbc0038I Initial state - 5 integers unsatisfied sum - 1.7619
# Cbc0038I Pass   1: suminf.    1.72727 (5) obj. -5.37345 iterations 5
# Cbc0038I Pass   2: suminf.    0.00000 (0) obj. 0 iterations 5
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 143 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 61 rows 150 columns, reduced to 9 rows 7 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -6.424 (0.01 seconds)
# Cbc0038I Round again with cutoff of -6.54914
# Cbc0038I Reduced cost fixing fixed 81 variables on major pass 2
# Cbc0038I Pass   3: suminf.    1.76190 (5) obj. -7.67448 iterations 1
# Cbc0038I Pass   4: suminf.    0.24780 (4) obj. -6.54914 iterations 4
# Cbc0038I Pass   5: suminf.    0.20634 (4) obj. -6.54914 iterations 2
# Cbc0038I Pass   6: suminf.    0.80000 (4) obj. -7.15272 iterations 6
# Cbc0038I Solution found of -6.8299
# Cbc0038I Before mini branch and bound, 143 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 61 rows 150 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -6.9989
# Cbc0038I Reduced cost fixing fixed 88 variables on major pass 3
# Cbc0038I Pass   7: suminf.    1.76190 (5) obj. -7.67448 iterations 0
# Cbc0038I Pass   8: suminf.    1.13841 (4) obj. -6.9989 iterations 4
# Cbc0038I Pass   9: suminf.    0.94793 (4) obj. -6.9989 iterations 2
# Cbc0038I Pass  10: suminf.    0.80000 (4) obj. -7.15272 iterations 5
# Cbc0038I Pass  11: suminf.    0.41678 (4) obj. -6.9989 iterations 5
# Cbc0038I Pass  12: suminf.    1.84211 (5) obj. -7.59676 iterations 13
# Cbc0038I Pass  13: suminf.    1.76190 (5) obj. -7.67448 iterations 6
# Cbc0038I Pass  14: suminf.    1.13841 (4) obj. -6.9989 iterations 4
# Cbc0038I Pass  15: suminf.    0.94793 (4) obj. -6.9989 iterations 2
# Cbc0038I Pass  16: suminf.    0.80000 (4) obj. -7.15272 iterations 5
# Cbc0038I Pass  17: suminf.    0.41678 (4) obj. -6.9989 iterations 5
# Cbc0038I Pass  18: suminf.    1.84211 (5) obj. -7.59676 iterations 13
# Cbc0038I Pass  19: suminf.    1.76190 (5) obj. -7.67448 iterations 6
# Cbc0038I Pass  20: suminf.    1.13841 (4) obj. -6.9989 iterations 4
# Cbc0038I Pass  21: suminf.    0.94793 (4) obj. -6.9989 iterations 2
# Cbc0038I Pass  22: suminf.    0.80000 (4) obj. -7.15272 iterations 5
# Cbc0038I Pass  23: suminf.    0.41678 (4) obj. -6.9989 iterations 4
# Cbc0038I Pass  24: suminf.    1.84211 (5) obj. -7.59676 iterations 12
# Cbc0038I Pass  25: suminf.    1.76190 (5) obj. -7.67448 iterations 6
# Cbc0038I Pass  26: suminf.    1.13841 (4) obj. -6.9989 iterations 4
# Cbc0038I Pass  27: suminf.    0.94793 (4) obj. -6.9989 iterations 2
# Cbc0038I Pass  28: suminf.    0.80000 (4) obj. -7.15272 iterations 5
# Cbc0038I Pass  29: suminf.    0.41678 (4) obj. -6.9989 iterations 5
# Cbc0038I Pass  30: suminf.    1.84211 (5) obj. -7.59676 iterations 13
# Cbc0038I Pass  31: suminf.    1.76190 (5) obj. -7.67448 iterations 6
# Cbc0038I Pass  32: suminf.    1.13841 (4) obj. -6.9989 iterations 4
# Cbc0038I Pass  33: suminf.    0.94793 (4) obj. -6.9989 iterations 2
# Cbc0038I Pass  34: suminf.    0.80000 (4) obj. -7.15272 iterations 5
# Cbc0038I Pass  35: suminf.    0.41678 (4) obj. -6.9989 iterations 5
# Cbc0038I Pass  36: suminf.    1.84211 (5) obj. -7.59676 iterations 13
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 141 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 61 rows 150 columns, reduced to 9 rows 8 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -6.8299 - took 0.02 seconds
# Cbc0012I Integer solution of -6.8299 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0038I Full problem 61 rows 150 columns, reduced to 6 rows 5 columns
# Cbc0031I 1 added rows had average density of 3
# Cbc0013I At root node, 11 cuts changed objective from -7.6744762 to -6.8299 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 19.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 1 row cuts average 80.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (OddWheel) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (TwoMirCuts) - 4 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 8 (ZeroHalf) - 4 row cuts average 112.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -6.8299, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 84 variables fixed on reduced cost
# Cuts at root node changed objective from -7.67448 to -6.8299
# Probing was tried 1 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# OddWheel was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -6.82990000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04

# %%
with open('solution.txt', 'r') as f:
    for v in model.get_variables():
        v.set_value(0)
    for line in f:
        if 'objective value' in line:
            continue
        words = line.split()
        var = model.get_variable(words[1])
        var.set_value(float(words[2]))

# %%
print("LINEUP")
for p in players:
    if lineup[p].get_value() > 0.5:
        print(p, gk_data.loc[p])
print("BENCH")
for p in players:
    if bench[p].get_value() > 0.5:
        print(p, gk_data.loc[p])
# Out:
# LINEUP
# 522 Pos                   G
# Name            Forster
# BV                    4
# SV                    4
# Team        Southampton
# 27_xMins             81
# 27_Pts            6.424
# Name: 522, dtype: object
# BENCH
# 7 Pos               G
# Name           Leno
# BV                5
# SV                5
# Team        Arsenal
# 27_xMins         88
# 27_Pts        4.059
# Name: 7, dtype: object
